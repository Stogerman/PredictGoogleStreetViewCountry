# %%
import tensorflow as tf
import pathlib
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import cv2 as cv
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Flatten, Dense, Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dropout, BatchNormalization, LeakyReLU, Activation

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
country_images_root = pathlib.Path("/home/pascal_steiger/Downloads/data15/")

# %%
def load_image_paths(container_path):
    image_dir = pathlib.Path(container_path)
    folders = [directory for directory in image_dir.iterdir() if directory.is_dir()]
    categories = [fo.name for fo in folders]

    descr = "A image classification dataset"
    image_paths = []
    flat_data = []
    target = []
    count = 0
    train_img_path = []
    train_label = []
    for i, direc in enumerate(folders):
        for file in direc.iterdir():
            count += 1
            train_img_path.append(str(file))
            train_label.append(categories[i])

    X = np.array(train_img_path)
    y = np.array(train_label)
    catStringArr = np.array(categories)

    return X, y, catStringArr

# %%
X = []
y = []
X, y, labelStringArr = load_image_paths("/home/pascal_steiger/Downloads/data15/")
img_df = pd.DataFrame(zip(X, y), columns=["path", "label"])

img_df.sample(n=10)
# Out:
#                                                     path label
# 14757  /home/pascal_steiger/Downloads/data15/SWE/img_...   SWE
# 4246   /home/pascal_steiger/Downloads/data15/GBR/img_...   GBR
# 11086  /home/pascal_steiger/Downloads/data15/POL/img_...   POL
# 6529   /home/pascal_steiger/Downloads/data15/FIN/img_...   FIN
# 4627   /home/pascal_steiger/Downloads/data15/GBR/img_...   GBR
# 5962   /home/pascal_steiger/Downloads/data15/AUT/img_...   AUT
# 4332   /home/pascal_steiger/Downloads/data15/GBR/img_...   GBR
# 4256   /home/pascal_steiger/Downloads/data15/GBR/img_...   GBR
# 7678   /home/pascal_steiger/Downloads/data15/NOR/img_...   NOR
# 349    /home/pascal_steiger/Downloads/data15/MKD/img_...   MKD

# %%
train_df, test_df = train_test_split(img_df, shuffle=True, test_size=0.2, random_state=42)


print(train_df.sample(n=5))
print(train_df.shape)
print(test_df.sample(n=5))
print(test_df.shape)
# Out:
#                                                    path label
# 3348  /home/pascal_steiger/Downloads/data15/ITA/img_...   ITA
# 3047  /home/pascal_steiger/Downloads/data15/ITA/img_...   ITA
# 8739  /home/pascal_steiger/Downloads/data15/PRT/img_...   PRT
# 2527  /home/pascal_steiger/Downloads/data15/IRL/img_...   IRL
# 3845  /home/pascal_steiger/Downloads/data15/ITA/img_...   ITA
# (12012, 2)
#                                                     path label
# 10442  /home/pascal_steiger/Downloads/data15/EST/img_...   EST
# 4252   /home/pascal_steiger/Downloads/data15/GBR/img_...   GBR
# 13060  /home/pascal_steiger/Downloads/data15/DNK/img_...   DNK
# 11160  /home/pascal_steiger/Downloads/data15/POL/img_...   POL
# 9271   /home/pascal_steiger/Downloads/data15/BEL/img_...   BEL
# (3003, 2)

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range=0.15,
    zoom_range=0.15,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_dataframe(
        dataframe=train_df,
        x_col="path",
        y_col="label",
        target_size=(500, 500),
        batch_size=32,
        class_mode="sparse",
        seed=42
)


validation_generator = test_datagen.flow_from_dataframe(
        dataframe=test_df,
        x_col="path",
        y_col="label",
        target_size=(500, 500),
        batch_size=32,
        class_mode="sparse",
        seed=42
)
# Out:
# Found 12012 validated image filenames belonging to 15 classes.
# Found 3003 validated image filenames belonging to 15 classes.

# %%
# create function to build neural network

def build():
    network = Sequential(name='DCNN')

    network.add(
        Conv2D(
            filters=64,
            kernel_size=(5,5),
            input_shape=(500,500, 3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d'
        )
    )
    
    network.add(BatchNormalization(name='batchnorm_0'))
    
    network.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_0'))
    
    network.add(
        Conv2D(
            filters=64,
            kernel_size=(5,5),
            input_shape=(250,250, 3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_1'
        )
    )
    network.add(BatchNormalization(name='batchnorm_1'))
    network.add(
        Conv2D(
            filters=64,
            kernel_size=(5,5),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_2'
        )
    )
    network.add(BatchNormalization(name='batchnorm_2'))
    
    network.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_1'))
    network.add(Dropout(0.4, name='dropout_1'))

    network.add(
        Conv2D(
            filters=128,
            kernel_size=(3,3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_4'
        )
    )
    network.add(BatchNormalization(name='batchnorm_4'))
    
    network.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_2'))
    network.add(Dropout(0.4, name='dropout_2'))



    network.add(Flatten(name='flatten'))
        
    network.add(
        Dense(
            128,
            activation='elu',
            kernel_initializer='he_normal',
            name='dense_1'
        )
    )
    network.add(BatchNormalization(name='batchnorm_7'))
    
    network.add(Dropout(0.6, name='dropout_4'))
    
    network.add(
        Dense(
            26,
            activation='softmax',
            name='out_layer'
        )
    )
    
    optimizer = tf.optimizers.Nadam(
        learning_rate=0.001,
        beta_1=0.9,
        beta_2=0.999,
        epsilon=1e-07,
        name='Nadam'
    )
    
    network.compile(
        loss='sparse_categorical_crossentropy',
        optimizer=optimizer,
        metrics=[tf.keras.metrics.SparseCategoricalAccuracy()]
    )
    
    network.summary()
    
    return network

# %%
early_stopping = EarlyStopping(
    monitor='val_sparse_categorical_accuracy',
    min_delta=0.00005,
    patience=11,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_sparse_categorical_accuracy',
    factor=0.5,
    patience=7,
    min_lr=1e-7,
    verbose=1,
)

callbacks = [
    early_stopping,
    lr_scheduler,
]

# %%
with tf.device("/device:GPU:1"):
    model = build()
    model.compile(optimizer = tf.optimizers.Nadam(),
              loss = 'sparse_categorical_crossentropy',
              metrics=['sparse_categorical_accuracy'])
# Out:
# Model: "DCNN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 500, 500, 64)      4864
# _________________________________________________________________
# batchnorm_0 (BatchNormalizat (None, 500, 500, 64)      256
# _________________________________________________________________
# maxpool2d_0 (MaxPooling2D)   (None, 250, 250, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 250, 250, 64)      102464
# _________________________________________________________________
# batchnorm_1 (BatchNormalizat (None, 250, 250, 64)      256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 250, 250, 64)      102464
# _________________________________________________________________
# batchnorm_2 (BatchNormalizat (None, 250, 250, 64)      256
# _________________________________________________________________
# maxpool2d_1 (MaxPooling2D)   (None, 125, 125, 64)      0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 125, 125, 64)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 125, 125, 128)     73856
# _________________________________________________________________
# batchnorm_4 (BatchNormalizat (None, 125, 125, 128)     512
# _________________________________________________________________
# maxpool2d_2 (MaxPooling2D)   (None, 62, 62, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 62, 62, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 492032)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               62980224
# _________________________________________________________________
# batchnorm_7 (BatchNormalizat (None, 128)               512
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# out_layer (Dense)            (None, 26)                3354
# =================================================================
# Total params: 63,269,018
# Trainable params: 63,268,122
# Non-trainable params: 896
# _________________________________________________________________

# %%
with tf.device("/device:GPU:1"):
    history = model.fit(train_generator,
      #steps_per_epoch=2000 // 32,  
      epochs=100,
      verbose=1,
      validation_data = validation_generator,
      validation_steps=8,
      callbacks = callbacks)
# Out:
# Epoch 1/100
# 376/376 [==============================] - 668s 2s/step - loss: 3.2056 - sparse_categorical_accuracy: 0.1400 - val_loss: 29.7767 - val_sparse_categorical_accuracy: 0.1055
# Epoch 2/100
# 376/376 [==============================] - 652s 2s/step - loss: 2.7673 - sparse_categorical_accuracy: 0.1771 - val_loss: 2.9950 - val_sparse_categorical_accuracy: 0.1758
# Epoch 3/100
# 376/376 [==============================] - 653s 2s/step - loss: 2.4281 - sparse_categorical_accuracy: 0.2289 - val_loss: 2.4423 - val_sparse_categorical_accuracy: 0.2656
# Epoch 4/100
# 376/376 [==============================] - 656s 2s/step - loss: 2.3134 - sparse_categorical_accuracy: 0.2546 - val_loss: 2.1420 - val_sparse_categorical_accuracy: 0.3203
# Epoch 5/100
# 376/376 [==============================] - 656s 2s/step - loss: 2.2534 - sparse_categorical_accuracy: 0.2766 - val_loss: 17.4487 - val_sparse_categorical_accuracy: 0.1797
# Epoch 6/100
# 376/376 [==============================] - 654s 2s/step - loss: 2.1893 - sparse_categorical_accuracy: 0.2945 - val_loss: 3.3113 - val_sparse_categorical_accuracy: 0.2109
# Epoch 7/100
# 376/376 [==============================] - 652s 2s/step - loss: 2.1428 - sparse_categorical_accuracy: 0.3144 - val_loss: 74.2425 - val_sparse_categorical_accuracy: 0.1484
# Epoch 8/100
# 376/376 [==============================] - 655s 2s/step - loss: 2.1128 - sparse_categorical_accuracy: 0.3191 - val_loss: 2.2011 - val_sparse_categorical_accuracy: 0.3203
# Epoch 9/100
# 376/376 [==============================] - 653s 2s/step - loss: 2.0843 - sparse_categorical_accuracy: 0.3295 - val_loss: 2.1381 - val_sparse_categorical_accuracy: 0.3047
# Epoch 10/100
# 376/376 [==============================] - 652s 2s/step - loss: 2.0629 - sparse_categorical_accuracy: 0.3313 - val_loss: 4.8628 - val_sparse_categorical_accuracy: 0.3320
# Epoch 11/100
# 376/376 [==============================] - 654s 2s/step - loss: 2.0433 - sparse_categorical_accuracy: 0.3475 - val_loss: 1.9640 - val_sparse_categorical_accuracy: 0.3438
# Epoch 12/100
# 376/376 [==============================] - 656s 2s/step - loss: 2.0035 - sparse_categorical_accuracy: 0.3557 - val_loss: 2.1113 - val_sparse_categorical_accuracy: 0.4180
# Epoch 13/100
# 376/376 [==============================] - 654s 2s/step - loss: 1.9864 - sparse_categorical_accuracy: 0.3573 - val_loss: 3.1140 - val_sparse_categorical_accuracy: 0.2227
# Epoch 14/100
# 376/376 [==============================] - 657s 2s/step - loss: 1.9728 - sparse_categorical_accuracy: 0.3638 - val_loss: 2.8330 - val_sparse_categorical_accuracy: 0.3203
# Epoch 15/100
# 376/376 [==============================] - 654s 2s/step - loss: 1.9758 - sparse_categorical_accuracy: 0.3677 - val_loss: 4.2567 - val_sparse_categorical_accuracy: 0.1016
# Epoch 16/100
# 376/376 [==============================] - 650s 2s/step - loss: 1.9741 - sparse_categorical_accuracy: 0.3638 - val_loss: 2.0326 - val_sparse_categorical_accuracy: 0.3750
# Epoch 17/100
# 376/376 [==============================] - 652s 2s/step - loss: 1.9370 - sparse_categorical_accuracy: 0.3805 - val_loss: 2.1736 - val_sparse_categorical_accuracy: 0.3047
# Epoch 18/100
# 376/376 [==============================] - 654s 2s/step - loss: 1.9012 - sparse_categorical_accuracy: 0.3852 - val_loss: 3.7213 - val_sparse_categorical_accuracy: 0.2109
# Epoch 19/100
# 376/376 [==============================] - 658s 2s/step - loss: 1.8798 - sparse_categorical_accuracy: 0.4001 - val_loss: 2.2784 - val_sparse_categorical_accuracy: 0.2656
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 20/100
# 376/376 [==============================] - 645s 2s/step - loss: 1.8111 - sparse_categorical_accuracy: 0.4120 - val_loss: 1.7830 - val_sparse_categorical_accuracy: 0.4219
# Epoch 21/100
# 376/376 [==============================] - 655s 2s/step - loss: 1.7793 - sparse_categorical_accuracy: 0.4218 - val_loss: 2.2465 - val_sparse_categorical_accuracy: 0.3320
# Epoch 22/100
# 376/376 [==============================] - 651s 2s/step - loss: 1.7698 - sparse_categorical_accuracy: 0.4288 - val_loss: 2.3011 - val_sparse_categorical_accuracy: 0.3789
# Epoch 23/100
# 376/376 [==============================] - 653s 2s/step - loss: 1.7412 - sparse_categorical_accuracy: 0.4326 - val_loss: 5.3442 - val_sparse_categorical_accuracy: 0.1523
# Epoch 24/100
# 376/376 [==============================] - 650s 2s/step - loss: 1.7413 - sparse_categorical_accuracy: 0.4327 - val_loss: 2.7618 - val_sparse_categorical_accuracy: 0.2773
# Epoch 25/100
# 376/376 [==============================] - 648s 2s/step - loss: 1.7266 - sparse_categorical_accuracy: 0.4376 - val_loss: 1.6640 - val_sparse_categorical_accuracy: 0.4688
# Epoch 26/100
# 376/376 [==============================] - 658s 2s/step - loss: 1.7064 - sparse_categorical_accuracy: 0.4423 - val_loss: 2.3590 - val_sparse_categorical_accuracy: 0.2734
# Epoch 27/100
# 376/376 [==============================] - 649s 2s/step - loss: 1.6873 - sparse_categorical_accuracy: 0.4505 - val_loss: 1.7894 - val_sparse_categorical_accuracy: 0.4375
# Epoch 28/100
# 376/376 [==============================] - 653s 2s/step - loss: 1.6729 - sparse_categorical_accuracy: 0.4569 - val_loss: 1.7573 - val_sparse_categorical_accuracy: 0.4492
# Epoch 29/100
# 376/376 [==============================] - 656s 2s/step - loss: 1.6677 - sparse_categorical_accuracy: 0.4550 - val_loss: 1.5752 - val_sparse_categorical_accuracy: 0.5000
# Epoch 30/100
# 376/376 [==============================] - 649s 2s/step - loss: 1.6578 - sparse_categorical_accuracy: 0.4590 - val_loss: 2.1230 - val_sparse_categorical_accuracy: 0.4570
# Epoch 31/100
# 376/376 [==============================] - 649s 2s/step - loss: 1.6529 - sparse_categorical_accuracy: 0.4629 - val_loss: 2.9462 - val_sparse_categorical_accuracy: 0.2266
# Epoch 32/100
# 376/376 [==============================] - 653s 2s/step - loss: 1.6211 - sparse_categorical_accuracy: 0.4692 - val_loss: 1.8125 - val_sparse_categorical_accuracy: 0.4023
# Epoch 33/100
# 376/376 [==============================] - 650s 2s/step - loss: 1.6283 - sparse_categorical_accuracy: 0.4679 - val_loss: 1.7759 - val_sparse_categorical_accuracy: 0.4609
# Epoch 34/100
# 376/376 [==============================] - 652s 2s/step - loss: 1.6098 - sparse_categorical_accuracy: 0.4704 - val_loss: 2.0486 - val_sparse_categorical_accuracy: 0.3008
# Epoch 35/100
# 376/376 [==============================] - 652s 2s/step - loss: 1.5995 - sparse_categorical_accuracy: 0.4769 - val_loss: 1.6719 - val_sparse_categorical_accuracy: 0.4492
# Epoch 36/100
# 376/376 [==============================] - 646s 2s/step - loss: 1.5844 - sparse_categorical_accuracy: 0.4829 - val_loss: 1.8164 - val_sparse_categorical_accuracy: 0.3984
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 37/100
# 376/376 [==============================] - 650s 2s/step - loss: 1.5416 - sparse_categorical_accuracy: 0.4957 - val_loss: 1.8496 - val_sparse_categorical_accuracy: 0.3867
# Epoch 38/100
# 376/376 [==============================] - 651s 2s/step - loss: 1.5465 - sparse_categorical_accuracy: 0.4903 - val_loss: 1.6560 - val_sparse_categorical_accuracy: 0.4297
# Epoch 39/100
# 376/376 [==============================] - 652s 2s/step - loss: 1.5252 - sparse_categorical_accuracy: 0.4953 - val_loss: 1.7084 - val_sparse_categorical_accuracy: 0.4219
# Epoch 40/100
# 376/376 [==============================] - 653s 2s/step - loss: 1.5199 - sparse_categorical_accuracy: 0.5025 - val_loss: 1.5558 - val_sparse_categorical_accuracy: 0.4766
# Restoring model weights from the end of the best epoch.
# Epoch 00040: early stopping

# %%
with tf.device("/device:GPU:1"):
    model.save('CNN_v2_fullNet_attempt15.h5')

# %%
# plot training and validation metrics

sns.set()
fig = plt.figure(0, (12, 4))

ax = plt.subplot(1, 2, 1)
sns.lineplot(x=history.epoch, y=history.history['sparse_categorical_accuracy'], label='train')
sns.lineplot(x=history.epoch, y=history.history['val_sparse_categorical_accuracy'], label='valid')
plt.title('Accuracy')
plt.tight_layout()

ax = plt.subplot(1, 2, 2)
sns.lineplot(x=history.epoch, y=history.history['loss'], label='train')
sns.lineplot(x=history.epoch, y=history.history['val_loss'], label='valid')
plt.title('Loss')
plt.tight_layout()

plt.savefig('CNN(500,500)_v2_attempt15.png')

plt.show()

# %%
def make_prediction(path, model, size=(250,250)):
    d = {'path': [path], 'label': [os.path.dirname(path)]}
    df = pd.DataFrame(data=d)
    pred_gen = ImageDataGenerator(rescale=1./255)
    pred_generator = pred_gen.flow_from_dataframe(
        dataframe=df,
        x_col="path",
        y_col="label",
        target_size=size,
        batch_size=1,
        shuffle=False,
        class_mode="sparse",
        seed=42
    )
    res = model.predict(pred_generator)
    return (labelStringArr[np.argmax(res)], res[0][np.argmax(res)])

# %%
make_prediction("/mnt/data/data/POL/img_POL_50.114902597259785,21.71049290647834_180.jpg", model)

# %%
import seaborn as sns
plt.figure(figsize=(12,4))
sns.countplot(x='label', data=train_df)

# %%
print("on valid data")
pred1=model.evaluate(X_valid,Y_valid)
print("accuaracy", str(pred1[1]*100))
print("Total loss",str(pred1[0]*100))
